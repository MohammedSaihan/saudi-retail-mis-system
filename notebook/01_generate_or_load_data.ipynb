# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\skill\\Play-code\\saudi-retail-mis-system\\Raw_Data\\Saudi_retail.csv')

# %%
df
# Out:
#         Invoice_ID        Date Customer_ID                    Product  \
# 0           570055  2023-01-01  CUST-16807        Miswak Pack (10pcs)
# 1           570155  2023-01-01  CUST-11308  Mabkhara (Incense Burner)
# 2           570243  2023-01-01  CUST-10212               Ceramic Vase
# 3           570696  2023-01-01  CUST-17978          Rose Water Bottle
# 4           570741  2023-01-01  CUST-12436       Dates Gift Box (1kg)
# ...            ...         ...         ...                        ...
# 104995      596623  2025-12-30  CUST-15383       Thobe - White Cotton
# 104996      597035  2025-12-30  CUST-11640          Arabic Sweets Box
# 104997      597058  2025-12-30  CUST-15039       Thobe - White Cotton
# 104998      597348  2025-12-30  CUST-10920          Arabic Sweets Box
# 104999      597527  2025-12-30  CUST-15736               Ceramic Vase
#
#         Quantity  Unit_Price_SAR     City
# 0              5           19.45  Madinah
# 1              8           44.01  Madinah
# 2              5           95.21   Dammam
# 3              1           26.18   Riyadh
# 4              3           68.62   Khobar
# ...          ...             ...      ...
# 104995         5          126.70   Makkah
# 104996         2           56.26    Tabuk
# 104997         1          204.57   Dammam
# 104998        12           75.20   Khobar
# 104999         1           45.11   Riyadh
#
# [105000 rows x 7 columns]

# %%
# data cleaning
df.columns = df.columns.str.strip().str.lower()
df = df.drop_duplicates() # remove duplicates

# %%
df.columns
# Out:
# Index(['invoice_id', 'date', 'customer_id', 'product', 'quantity',
#        'unit_price_sar', 'city'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105000 entries, 0 to 104999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   invoice_id      105000 non-null  int64
#  1   date            105000 non-null  datetime64[ns]
#  2   customer_id     105000 non-null  object
#  3   product         105000 non-null  object
#  4   quantity        105000 non-null  int64
#  5   unit_price_sar  105000 non-null  float64
#  6   city            105000 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 5.6+ MB

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True, format='mixed')

# %%
df.isnull().sum()
# Out:
# invoice_id        0
# date              0
# customer_id       0
# product           0
# quantity          0
# unit_price_sar    0
# city              0
# dtype: int64

# %%
df = df.drop_duplicates()
